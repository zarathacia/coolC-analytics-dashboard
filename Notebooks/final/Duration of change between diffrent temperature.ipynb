# %%
import datetime

from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data="/content/drive/MyDrive/P2M/Data/Data.csv"
df = pd.read_csv(data)
df.head()
# Out:
#    Mvt  Temp        Date      Time  TempExt
# 0  0.0  29.0  2021-08-10  00:00:04       36
# 1  1.0  30.0  2021-08-10  00:00:08       36
# 2  0.0  30.0  2021-08-10  00:00:12       36
# 3  1.0  29.0  2021-08-10  00:00:14       36
# 4  0.0  29.0  2021-08-10  00:00:21       36

# %%
df1=df.copy()
df1.head()
# Out:
#    Mvt  Temp        Date      Time  TempExt
# 0  0.0  29.0  2021-08-10  00:00:04       36
# 1  1.0  30.0  2021-08-10  00:00:08       36
# 2  0.0  30.0  2021-08-10  00:00:12       36
# 3  1.0  29.0  2021-08-10  00:00:14       36
# 4  0.0  29.0  2021-08-10  00:00:21       36

# %%
indexNames = df1[ df1['Temp'] <0 ].index
indexNames
# Out:
# Int64Index([505994], dtype='int64')

# %%
df1 = df1.drop(columns="Mvt")
df1 = df1.drop(columns="TempExt")

# %%
df1.head()
# Out:
#    Temp        Date      Time
# 0  29.0  2021-08-10  00:00:04
# 1  30.0  2021-08-10  00:00:08
# 2  30.0  2021-08-10  00:00:12
# 3  29.0  2021-08-10  00:00:14
# 4  29.0  2021-08-10  00:00:21

# %%
len(df1)
# Out:
# 3722750

# %%
df1["Date"][1]
# Out:
# '2021-08-10'

# %%
df1.head()
# Out:
#    Temp        Date      Time
# 0  29.0  2021-08-10  00:00:04
# 1  30.0  2021-08-10  00:00:08
# 2  30.0  2021-08-10  00:00:12
# 3  29.0  2021-08-10  00:00:14
# 4  29.0  2021-08-10  00:00:21

# %%
df1['DateTime']=pd.to_datetime(df1['Date'] + ' ' + df1['Time'])
df1['date'] = pd.to_datetime(df1['DateTime'], format='%d-%m-%Y %H:%M')
df1 = df1.drop(columns="Date")
df1 = df1.drop(columns="Time")

# %%
df1.head()
# Out:
#    Temp            DateTime                date
# 0  29.0 2021-08-10 00:00:04 2021-08-10 00:00:04
# 1  30.0 2021-08-10 00:00:08 2021-08-10 00:00:08
# 2  30.0 2021-08-10 00:00:12 2021-08-10 00:00:12
# 3  29.0 2021-08-10 00:00:14 2021-08-10 00:00:14
# 4  29.0 2021-08-10 00:00:21 2021-08-10 00:00:21

# %%
df1 = df1.drop(columns="DateTime")

# %%
df1["seconds"] = df1["date"] - datetime.datetime(2021, 8, 10)
df1["seconds"] = df1["seconds"].dt.total_seconds()

# %%
df1.head()
# Out:
#    Temp                date  seconds
# 0  29.0 2021-08-10 00:00:04      4.0
# 1  30.0 2021-08-10 00:00:08      8.0
# 2  30.0 2021-08-10 00:00:12     12.0
# 3  29.0 2021-08-10 00:00:14     14.0
# 4  29.0 2021-08-10 00:00:21     21.0

# %%
df1['durée'] =df1['seconds'] -  df1['seconds'].shift(1)

# %%
df1.head()
# Out:
#    Temp                date  seconds  durée
# 0  29.0 2021-08-10 00:00:04      4.0    NaN
# 1  30.0 2021-08-10 00:00:08      8.0    4.0
# 2  30.0 2021-08-10 00:00:12     12.0    4.0
# 3  29.0 2021-08-10 00:00:14     14.0    2.0
# 4  29.0 2021-08-10 00:00:21     21.0    7.0
